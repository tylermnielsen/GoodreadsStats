# %% [markdown]
# # Stats from Goodreads Bookshelf

# %%
import pandas as pd
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
import ipywidgets as widgets
import json

# %%
csvPath = os.path.join(".", "goodreads_library_export.csv")

# %%
booklist = pd.read_csv(csvPath)

booklist.insert(list(booklist).index("Date Read"), "Year Read", 
                [int(i[:4]) if str(i).find("/") != -1 else -1 for i in booklist["Date Read"]],
                True)
booklist.insert(list(booklist).index("Date Read"), "Month Read", 
                [int(i[5:7]) if str(i).find("/") != -1 else -1 for i in booklist["Date Read"]], 
                True)
booklist.insert(list(booklist).index("Date Read"), "Day Read", 
                [int(i[8:]) if str(i).find("/") != -1 else -1 for i in booklist["Date Read"]], 
                True)

print(booklist.dtypes)
# Out:
# Book Id                         int64
# Title                          object
# Author                         object
# Author l-f                     object
# Additional Authors             object
# ISBN                           object
# ISBN13                         object
# My Rating                       int64
# Average Rating                float64
# Publisher                      object
# Binding                        object
# Number of Pages               float64
# Year Published                float64
# Original Publication Year     float64
# Year Read                       int64
# Month Read                      int64
# Day Read                        int64
# Date Read                      object
# Date Added                     object
# Bookshelves                    object
# Bookshelves with positions     object
# Exclusive Shelf                object
# My Review                     float64
# Spoiler                       float64
# Private Notes                 float64
# Read Count                      int64
# Owned Copies                    int64
# dtype: object

# %% [markdown]
# ### Filtering

# %%
read = booklist[booklist["Exclusive Shelf"] == "read"].reset_index(drop=True)
to_read = booklist[booklist["Exclusive Shelf"] == "to-read"].reset_index(drop=True)
reading = booklist[booklist["Exclusive Shelf"] == "currently-reading"].reset_index(drop=True)

# %% [markdown]
# # Books by year

# %%
byYearRead = read[["Title","Date Read"]]
byYearRead = byYearRead[byYearRead["Date Read"] == byYearRead["Date Read"]]
byYearRead["Date Read"] = [int(str(x)[0:4]) for x in byYearRead["Date Read"]]
x = np.arange(byYearRead["Date Read"].max(), byYearRead["Date Read"].min()-1,-1)

countMap = byYearRead.value_counts(subset=["Date Read"])

bar_fig, bar_ax = plt.subplots()

bar_ax.set_title("Books Read in Each Year", fontsize=20)
bar_ax.set_xlabel("Number of Books", fontsize=15)
years = [str(i) for i in x]
counts = [countMap[i] for i in x]
print(byYearRead.value_counts(subset=["Date Read"]))

rects = bar_ax.barh(years, counts, align="center", height=0.75)
bar_ax.bar_label(rects, counts, padding=-25, color="white", fontweight="bold", fontsize=15)

bar_ax.xaxis.grid(True, linestyle="--", which="major", color="grey", alpha=0.25)
bar_ax.set_ylabel("Year", fontsize=15)
pass
# Out:
# Date Read
# 2021         54
# 2023         41
# 2022         37
# 2020         36
# 2024         17
# dtype: int64

# %% [markdown]
# # General Scatterplot

# %%
cols = [i for i in list(booklist) if pd.api.types.is_numeric_dtype(booklist[i])]

listSelection = {
    "read": widgets.Checkbox(
        value=True,
        description="read",
        disabled=False,
        indent=False
    ),
    "toRead": widgets.Checkbox(
        value=False,
        description="to read",
        disabled=False,
        indent=False
    ),
    "continueReading": widgets.Checkbox(
        value=False,
        description="continue reading",
        disabled=False,
        indent=False
    )
}
# selectionBox = widgets.HBox(children=listSelection)

axisChoices = [
    widgets.Dropdown(
        options=cols,
        value=cols[0],
        description="X axis = ",
        disabled=False
    ),
    widgets.Dropdown(
        options=cols,
        value=cols[0],
        description="Y axis = ",
        disabled=False
    ),
]

# axisBox = widgets.VBox(children=axisChoices)

# display(selectionBox)
# display(axisBox)

@widgets.interact(readChoice=listSelection["read"], 
                  toReadChoice=listSelection["toRead"], 
                  continueReadingChoice=listSelection["continueReading"],
                  xAxis=axisChoices[0],
                  yAxis=axisChoices[1])
def on_change(readChoice, toReadChoice, continueReadingChoice, xAxis, yAxis):
    print((readChoice,toReadChoice,continueReadingChoice))
    print(xAxis, yAxis)
    scatter_fig, scatter_plt = plt.subplots()
    
    plotList = []
    if readChoice: plotList.append(read)
    if toReadChoice: plotList.append(to_read)
    if continueReadingChoice: plotList.append(reading)
    if(len(plotList) == 0): plotList.append(booklist)
    chosenList = pd.concat(plotList, ignore_index=True, sort=False)
    
    scatter_plt.scatter(x=chosenList[xAxis], y=chosenList[yAxis])
# outputs = widgets.interact(on_change, read=listSelection["read"])

# for i in listSelection: i.observe(on_change, names="value")
# Out:
# interactive(children=(Checkbox(value=True, description='read', indent=False), Checkbox(value=False, descriptio…

# %%
histchoice = widgets.Dropdown(
        options=cols,
        value=cols[0],
        description="Value = ",
        disabled=False
    )

binSlider = widgets.IntSlider(
    value=7,
    min=3,
    max=100,
    step=1,
    description='Bin Count:',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)

@widgets.interact(readChoice=listSelection["read"], 
                  toReadChoice=listSelection["toRead"], 
                  continueReadingChoice=listSelection["continueReading"],
                  histChoice=histchoice,
                  binCount=binSlider)
def process_hist_choice(readChoice, toReadChoice, continueReadingChoice, histChoice, binCount):
    hist_fig, hist_plt = plt.subplots()
    
    plotList = []
    if readChoice: plotList.append(read)
    if toReadChoice: plotList.append(to_read)
    if continueReadingChoice: plotList.append(reading)
    if(len(plotList) == 0): plotList.append(booklist)
    chosenList = pd.concat(plotList, ignore_index=True, sort=False)
    
    hist_plt.hist([i for i in chosenList[histChoice] if i != -1], binCount)
# Out:
# interactive(children=(Checkbox(value=True, description='read', indent=False), Checkbox(value=False, descriptio…

# %% [markdown]
# ## Using WikiData

# %%
import requests

def access_wikidata(query, search=True):
    endpoint = "https://www.wikidata.org/w/api.php"
    if search: 
        params = {
            "action": "wbsearchentities",
            "format": "json",
            "search": query,
            "language": "en"
        }
    else:
        params = {
            "action": "wbgetentities",
            "ids": query,
            "format": "json",
            "languages": "en"
        }
    try:
        return requests.get(endpoint, params=params)
    except:
        return "Error"

# %%
# test
data = access_wikidata("JRR Tolkien").json()
access_wikidata(data["search"][0]["id"], search=False).json()["entities"]["Q892"]["claims"]["P21"][0]["mainsnak"]["datavalue"]["value"]["id"]
# Out:
# 'Q6581097'

# %%
def getGender(name):
    searchResults = access_wikidata(name)
    try: 
        searchResults = searchResults.json()
        firstResultPage = access_wikidata(searchResults["search"][0]["id"], search=False).json()
        gender = firstResultPage["entities"][searchResults["search"][0]["id"]]["claims"]["P21"][0]["mainsnak"]["datavalue"]["value"]["id"]
        gender = access_wikidata(gender, search=False).json()
        gender = gender["entities"][next(iter(gender["entities"]))]["labels"]["en"]["value"]
        return gender
    except: 
        return "Error"

print("Starting...")
uniqueAuthor = {}
for i in read["Author"]:
    i = " ".join(i.split())
    if i in uniqueAuthor: continue
    currGen = getGender(i)
    print("%-*s %s" % (30, f"\"{i}\":", currGen))
    uniqueAuthor[i] = currGen
    
print("Done.")
# Out:
# Starting...
# "Anne Carson":                 female
# "Chuck Tingle":                transgender
# "Ryka Aoki":                   trans woman
# "Leslie Feinberg":             transgender
# "Ryoko Kui":                   female
# "Mark Z. Danielewski":         male
# "Katsuhiro Otomo":             Error
# "Terry Pratchett":             male
# "Melanie Gillman":             non-binary
# "Donna Tartt":                 female
# "Madeline Miller":             female
# "Becky Chambers":              female
# "T.J. Klune":                  male
# "James Baldwin":               Error
# "André Aciman":                male
# "Taylor Jenkins Reid":         female
# "Erin Morgenstern":            female
# "Amal El-Mohtar":              female
# "Audre Lorde":                 female

# %%
genderCounts = {}
genderCounts["female"] = 0
genderCounts["male"] = 0
for i in uniqueAuthor:
    if uniqueAuthor[i] not in genderCounts:
        genderCounts[uniqueAuthor[i]] = 0
    genderCounts[uniqueAuthor[i]] += 1
    

pie_fig, pie_plt = plt.subplots()


pie_plt.pie([genderCounts[i] for i in genderCounts], 
            labels=list(genderCounts), 
            radius=2.5, 
            autopct = lambda p : str(round(p, 2)) + "%",
            pctdistance = 0.9)

print("Author Gender")
print(genderCounts)
# Out:
# Author Gender
# {'female': 41, 'male': 101, 'transgender': 2, 'trans woman': 1, 'non-binary': 3, 'Error': 8, 'transmasculine': 1}

# %% [markdown]
# ## General

# %%
uniqueAuthor = {}
for i in read["Author"]:
    i = " ".join(i.split())
    if i in uniqueAuthor: continue
    uniqueAuthor[i] = "gender"

authorInfo = {}
print("Fetching author info")
for author in uniqueAuthor:
    try:
        print(f"Attempting {author}... ", end="")
        search_results = access_wikidata(author).json()
        top_result = access_wikidata(search_results["search"][0]["id"], search=False).json()
        authorInfo[author] = top_result
        print("Done.")
    except: 
        authorInfo[author] = "Failed"
        print("Failed")
        
print("Done fetching")
# Out:
# Fetching author info
# Attempting Anne Carson... Done.
# Attempting Chuck Tingle... Done.
# Attempting Ryka Aoki... Done.
# Attempting Leslie Feinberg... Done.
# Attempting Ryoko Kui... Done.
# Attempting Mark Z. Danielewski... Done.
# Attempting Katsuhiro Otomo... Done.
# Attempting Terry Pratchett... Done.
# Attempting Melanie Gillman... Done.
# Attempting Donna Tartt... Done.
# Attempting Madeline Miller... Done.
# Attempting Becky Chambers... Done.
# Attempting T.J. Klune... Done.
# Attempting James Baldwin... Done.
# Attempting André Aciman... Done.
# Attempting Taylor Jenkins Reid... Done.
# Attempting Erin Morgenstern... Done.
# Attempting Amal El-Mohtar... Done.
# Attempting Audre Lorde... Done.
# Attempting Heinz Heger... Done.
# Attempting Casey McQuiston... Done.
# Attempting Hanya Yanagihara... Done.
# Attempting Cam Marshall... Failed
# Attempting Ocean Vuong... Done.
# Attempting Matt Bors... Done.
# Attempting N.D. Stevenson... Done.
# Attempting Maia Kobabe... Done.
# Attempting Scarlett Gale... Failed
# Attempting Naomi Tucker... Done.
# Attempting Ray Bradbury... Done.
# Attempting Neil Gaiman... Done.
# Attempting Bryan Lee O'Malley... Done.
# Attempting Rachel Smythe... Done.
# Attempting Keith Giffen... Done.
# Attempting Frank Miller... Done.
# Attempting Sarah Andersen... Done.
# Attempting Matt Ruff... Done.
# Attempting H.P. Lovecraft... Done.
# Attempting Shelley Parker-Chan... Done.
# Attempting Michelle Alexander... Done.
# Attempting Daniel Keyes... Done.
# Attempting Anthony Burgess... Done.
# Attempting Malcolm X... Done.
# Attempting Ernesto Che Guevara... Done.
# Attempting Martha Wells... Done.
# Attempting Ursula K. Le Guin... Done.
# Attempting Robin Wall Kimmerer... Done.
# Attempting Brandon Sanderson... Done.
# Attempting Seanan McGuire... Done.
# Attempting Ibram X. Kendi... Done.
# Attempting Ernest Callenbach... Done.
# Attempting Benjamin Hoff... Done.
# Attempting Randall Munroe... Done.
# Attempting Emily St. John Mandel... Done.
# Attempting Sherman Alexie... Done.
# Attempting Shirley Jackson... Done.
# Attempting Philip K. Dick... Done.
# Attempting Ian Fleming... Done.
# Attempting William Golding... Done.
# Attempting Andy Weir... Done.
# Attempting William Gibson... Done.
# Attempting Alan Weisman... Done.
# Attempting Hermann Hesse... Done.
# Attempting Haruki Murakami... Done.
# Attempting James Riley... Done.
# Attempting Alastair Reynolds... Done.
# Attempting Susanna Clarke... Done.
# Attempting Edward Abbey... Done.
# Attempting Amor Towles... Done.
# Attempting Leslie Marmon Silko... Done.
# Attempting N. Scott Momaday... Done.
# Attempting Andreas Malm... Done.
# Attempting Victoria Schwab... Done.
# Attempting Sarah Winnemucca Hopkins... Done.
# Attempting F. Scott Fitzgerald... Done.
# Attempting Matt Haig... Done.
# Attempting Paul Slack... Done.
# Attempting Stephen Kinzer... Done.
# Attempting Leigh Bardugo... Done.
# Attempting Friedrich Nietzsche... Done.
# Attempting Reza Aslan... Done.
# Attempting Rodney Stark... Done.
# Attempting Washington Irving... Done.
# Attempting Karl Marx... Done.
# Attempting Chinua Achebe... Done.
# Attempting Elizabeth Kolbert... Done.
# Attempting Frank Herbert... Done.
# Attempting Shūsaku Endō... Done.
# Attempting Franklin W. Dixon... Done.
# Attempting Agatha Christie... Done.
# Attempting Viktor E. Frankl... Done.
# Attempting Oscar Wilde... Done.
# Attempting Orson Scott Card... Done.
# Attempting Ernest Cline... Done.
# Attempting Andrzej Sapkowski... Done.
# Attempting Delia Owens... Done.
# Attempting Isaac Asimov... Done.
# Attempting C.S. Lewis... Done.
# Attempting Douglas Adams... Done.
# Attempting J.R.R. Tolkien... Done.
# Attempting Kurt Vonnegut Jr.... Done.
# Attempting Jack London... Done.
# Attempting Margaret Atwood... Done.
# Attempting H.G. Wells... Done.
# Attempting Adam Savage... Done.
# Attempting Rick Riordan... Done.
# Attempting Rudyard Kipling... Done.
# Attempting S.E. Hinton... Done.
# Attempting Upton Sinclair... Done.
# Attempting Ken Kesey... Done.
# Attempting Edgar Allan Poe... Done.
# Attempting Charlotte Perkins Gilman... Done.
# Attempting Brandon Mull... Done.
# Attempting W.W. Jacobs... Done.
# Attempting J. Sheridan Le Fanu... Done.
# Attempting Mohsin Hamid... Done.
# Attempting Michael Moorcock... Done.
# Attempting Howard Pyle... Done.
# Attempting Charles Wheelan... Done.
# Attempting L. Frank Baum... Done.
# Attempting Lois Lowry... Done.
# Attempting Tui T. Sutherland... Done.
# Attempting Eoin Colfer... Done.
# Attempting Mary Wollstonecraft Shelley... Done.
# Attempting Bram Stoker... Done.
# Attempting Arthur C. Clarke... Done.
# Attempting Robert Ludlum... Done.
# Attempting Tom Clancy... Done.
# Attempting Jennifer A. Nielsen... Done.
# Attempting John Steinbeck... Done.
# Attempting Harper Lee... Done.
# Attempting George Orwell... Done.
# Attempting Emmuska Orczy... Done.
# Attempting Neal Shusterman... Done.
# Attempting Steven Novella... Done.
# Attempting Gene Doucette... Failed
# Attempting Lian Tanner... Done.
# Attempting Malcolm Gladwell... Done.
# Attempting Taran Matharu... Done.
# Attempting Tom Wolfe... Done.
# Attempting Elie Wiesel... Done.
# Attempting Laura Hillenbrand... Done.
# Attempting Greg Egan... Done.
# Attempting Michael Scott... Done.
# Attempting Lisa McMann... Done.
# Attempting Stuart Gibbs... Done.
# Attempting John Flanagan... Done.
# Attempting J.K. Rowling... Done.
# Attempting Obert Skye... Done.
# Attempting Rick Beyer... Done.
# Attempting Christopher Paolini... Done.
# Attempting Adam Hart-Davis... Done.
# Attempting Gaston Leroux... Done.
# Attempting Dan Brown... Done.
# Attempting S.J. Kincaid... Failed
# Attempting Neil deGrasse Tyson... Done.
# Attempting Paulo Coelho... Done.
# Done fetching

# %%
authorInfo["Chuck Tingle"]
# Out:
# {'entities': {'Q20090453': {'pageid': 21760269,
#    'ns': 0,
#    'title': 'Q20090453',
#    'lastrevid': 2224097146,
#    'modified': '2024-08-09T23:21:45Z',
#    'type': 'item',
#    'id': 'Q20090453',
#    'labels': {'en': {'language': 'en', 'value': 'Chuck Tingle'}},
#    'descriptions': {'en': {'language': 'en',
#      'value': 'anonymous American erotic writer'}},
#    'aliases': {'en': [{'language': 'en', 'value': 'Dr. Chuck Tingle'}]},
#    'claims': {'P31': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P31',
#        'hash': 'ad7d38a03cdd40cdc373de0dc4e7b7fcbccb31d9',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5,
#          'id': 'Q5'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$1A741949-5635-4C61-9F28-3D5F61FA7B33',
#       'rank': 'normal'}],
#     'P21': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P21',
#        'hash': '20f35700b519779aa2caefeaf246304df3f22cc3',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 189125,
#          'id': 'Q189125'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$6D0147C4-4A2E-45D5-A141-AE1A3F31DFC3',
#       'rank': 'normal',
#       'references': [{'hash': '0695c5361a3b6eea5d25cc794b7a4bb321e2e7e4',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '2df41d794463da20c09b9a0a36df48fec14e7a82',
#            'datavalue': {'value': 'https://drchucktingle.tumblr.com/post/703110927864725504/what-flavor-of-queer-are-you-if-thats-not-too',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P856': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P856',
#        'hash': 'bb0920cae380aaa5eb47542efc0c62335af69bb9',
#        'datavalue': {'value': 'https://www.chucktingle.com/',
#         'type': 'string'},
#        'datatype': 'url'},
#       'type': 'statement',
#       'qualifiers': {'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'hash': 'daf1c4fcb58181b02dff9cc89deb084004ddae4b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P407'],
#       'id': 'Q20090453$12C0BC7E-707A-4E56-B389-12B829DE2B54',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P106': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P106',
#        'hash': '70541c2eb72d85fa5f74008b4ee33b004a1ff7eb',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 36180,
#          'id': 'Q36180'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$48C25083-8B12-4035-A3C3-92B68DBB63D8',
#       'rank': 'normal'},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P106',
#        'hash': '468425a7d5990169ca1caa25413280f78cb985f8',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 18844224,
#          'id': 'Q18844224'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$8CE78706-8759-4117-B303-9E073A760451',
#       'rank': 'normal',
#       'references': [{'hash': 'a663edc6731753dc734058035aaecce8d268141f',
#         'snaks': {'P3452': [{'snaktype': 'value',
#            'property': 'P3452',
#            'hash': 'c37da4673fb16ec98214fcc9b5463afb182a6933',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 6614287,
#              'id': 'Q6614287'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '949efbe5702752b27a649957870d9223e727bfde',
#            'datavalue': {'value': {'time': '+2019-05-23T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'f30cbd35620c4ea6d0633aaf0210a8916130469b',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 8447,
#              'id': 'Q8447'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P3452', 'P813', 'P143']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P106',
#        'hash': '14be73d598149c03c06706621cc06dbd07d68193',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 2045208,
#          'id': 'Q2045208'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$715c469d-487a-87e5-1808-f3e18ea76aaa',
#       'rank': 'normal'}],
#     'P19': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P19',
#        'hash': 'fa69873adcfa9fec9c0e70763383ffa1d9c43458',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5889125,
#          'id': 'Q5889125'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$4F8C6FAB-D527-4EF6-BBCE-E4789E9193B1',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P742': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P742',
#        'hash': 'e3968bfc8fe0c108577b1b38929f9b6564542d05',
#        'datavalue': {'value': 'Dr. Chuck Tingle', 'type': 'string'},
#        'datatype': 'string'},
#       'type': 'statement',
#       'id': 'Q20090453$DBC82838-23CD-418C-BD1B-C25E604D0CEF',
#       'rank': 'normal',
#       'references': [{'hash': '8f08ac3e0839bdbc4c6eb8d671e772deb12ba423',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': '250b03083f7971a02473af3e43115ef521b1440d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 465,
#              'id': 'Q465'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P1050': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1050',
#        'hash': 'ead7642fadaedbe524bc07ce8a9031058f2170d3',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 161790,
#          'id': 'Q161790'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$3c4d1785-4c0a-226c-d6fe-1d100a468c4a',
#       'rank': 'normal',
#       'references': [{'hash': 'b8556914373c05c63732dbea2aaaff02c059e8c0',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '44aae1743bd9442051a8d8dea22ae6ada0f7b106',
#            'datavalue': {'value': 'https://www.chucktingle.com/questions.html',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P1683': [{'snaktype': 'value',
#            'property': 'P1683',
#            'hash': '9c82cd4a6bc1adfd0f6120165542bc86c98e9aaf',
#            'datavalue': {'value': {'text': "i have way of ASPERGER'S SYNDROME which made it hard to understand and relate in SOCIAL WAYS when i was a young buckaroo now i think i understand others more but i learn everyday as man name of chuck (worlds greatest author thank you)",
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}]},
#         'snaks-order': ['P854', 'P1683']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P1050',
#        'hash': 'c54a2c6ef03af217963f19ef38462a8290965a6a',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 467265,
#          'id': 'Q467265'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$69a233f6-4e77-1d0e-35ca-7d60a98846b3',
#       'rank': 'normal',
#       'references': [{'hash': '35b99307cfcecd6466b359804e1aaa9c7e7e218e',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'da0f9610fa4eea8d5856f6f1da0510c34c91b94b',
#            'datavalue': {'value': 'https://www.reddit.com/r/IAmA/comments/3vz1x7/iama_jon_tingle_son_of_bestselling_romance_author/',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '2a6b20e16a61e534b2588188b5b2616ec8acca6b',
#            'datavalue': {'value': {'time': '+2018-02-04T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P1683': [{'snaktype': 'value',
#            'property': 'P1683',
#            'hash': '458109e1fc9dc15386374b5efb9923c18d0ab701',
#            'datavalue': {'value': {'text': '[Tingle] is an autistic savant...',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}]},
#         'snaks-order': ['P854', 'P813', 'P1683']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P1050',
#        'hash': 'ae69692b6702232c1e61bbbed48f177cdc25fb62',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 41112,
#          'id': 'Q41112'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P1310': [{'snaktype': 'value',
#          'property': 'P1310',
#          'hash': '5d15a3d6f068d3291e030f87ce8bb13f19f6ecb1',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 20090453,
#            'id': 'Q20090453'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P1310'],
#       'id': 'Q20090453$6ef6b527-4fb7-e127-b437-de7e44056617',
#       'rank': 'deprecated',
#       'references': [{'hash': '2064d76059444fb1363253ecef18ae99667af813',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'da0f9610fa4eea8d5856f6f1da0510c34c91b94b',
#            'datavalue': {'value': 'https://www.reddit.com/r/IAmA/comments/3vz1x7/iama_jon_tingle_son_of_bestselling_romance_author/',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P1683': [{'snaktype': 'value',
#            'property': 'P1683',
#            'hash': '8eb8f9edf37f0256f4921e94d238592af3572f93',
#            'datavalue': {'value': {'text': '[Tingle] is an autistic savant, but also suffers from schizophrenia.',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}]},
#         'snaks-order': ['P854', 'P1683']},
#        {'hash': '6f325b49ad16a03be4ba513019773517949989ce',
#         'snaks': {'P5933': [{'snaktype': 'value',
#            'property': 'P5933',
#            'hash': '442c3ecf3eec433380ffd5441a75119811ba9ab2',
#            'datavalue': {'value': '1382136391174291458', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1683': [{'snaktype': 'value',
#            'property': 'P1683',
#            'hash': 'cda5dbb4e9e4bda0d0e65516873e415f35c278f0',
#            'datavalue': {'value': {'text': 'is there way for buckaroo who knows how the heck wikipedia works to take off part that says my way is having schizophrenia? this is not true and i have said it is not true for almost decade now. feel i am not listened to as neuroatypical bud when i say no',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}]},
#         'snaks-order': ['P5933', 'P1683']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P1050',
#        'hash': 'a576b9d456140ba9ab1b7f61a32e42083c482235',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 38404,
#          'id': 'Q38404'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$42e4dc5d-4eb9-339e-d2fc-b737d7e88f8b',
#       'rank': 'normal'}],
#     'P2002': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2002',
#        'hash': 'd0f112bb8236bc9410e23576fecfb26c53086cac',
#        'datavalue': {'value': 'ChuckTingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P6552': [{'snaktype': 'value',
#          'property': 'P6552',
#          'hash': '093604e25b76787d0f5649f707207b57cbefd2d8',
#          'datavalue': {'value': '2996351899', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': 'c24b258dec7cfdacc685d84ef0631d8a46736379',
#          'datavalue': {'value': {'time': '+2015-01-26T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P6552', 'P580'],
#       'id': 'Q20090453$46447932-4a45-fa9e-7454-2dea90260f08',
#       'rank': 'normal'}],
#     'P1233': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1233',
#        'hash': '477d5a385899af490fd3687421ea74f771bc6ef9',
#        'datavalue': {'value': '229140', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$29240291-D78E-4646-AD75-2D6691ECBFFE',
#       'rank': 'normal',
#       'references': [{'hash': 'dce89af7c063bcdc8021989761b5339c5f6054f8',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P4656': [{'snaktype': 'value',
#            'property': 'P4656',
#            'hash': '1307bc784fa8a03fcb220189c7019dd3c71be31c',
#            'datavalue': {'value': 'https://en.wikipedia.org/w/index.php?title=Chuck_Tingle&oldid=849183656',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P143', 'P4656']}]}],
#     'P136': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P136',
#        'hash': '7763336a968be39dbfbdd7c6deca62b5bdbeb104',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 110293051,
#          'id': 'Q110293051'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$342d5f47-4153-168e-8513-30fe974e8a40',
#       'rank': 'normal'},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P136',
#        'hash': 'a2f2e4c2b0288cbfd19f7753d1499d19b565b713',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 110292677,
#          'id': 'Q110292677'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$61ee3a1e-436a-01ff-7428-c4a0f626c77a',
#       'rank': 'normal'}],
#     'P27': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P27',
#        'hash': '52d0408c7915122e0519a22577f0cbdcb28f749b',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 30,
#          'id': 'Q30'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$380c321e-4012-562c-78b5-603d74a1498e',
#       'rank': 'normal'}],
#     'P4265': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P4265',
#        'hash': '3ea1b791a7c76cabadf982d291f2be56cb008e2e',
#        'datavalue': {'value': 'JonTingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$3b601426-4b6e-f852-e04c-0877e2f7f30a',
#       'rank': 'normal'}],
#     'P91': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P91',
#        'hash': '75a88229de5c55d34ca851096af9f350f178adc9',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 43200,
#          'id': 'Q43200'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$e6369ae2-456b-cb4e-9939-19810b4f4290',
#       'rank': 'normal',
#       'references': [{'hash': '6f8a24531f7cade7cdf2c73d3c2a9bcd6b60cd0e',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '72f3ad638398a6e283b19009ad927ef66db004b6',
#            'datavalue': {'value': 'https://twitter.com/ChuckTingle/status/1161725524676243456',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P2963': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2963',
#        'hash': 'b5cac3e084bf6187054445051f9833aabca6ccd6',
#        'datavalue': {'value': '10788353', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '4742bd7d64eb60cd35c3e6f7f5fdafaf5fef1b30',
#          'datavalue': {'value': {'time': '+2020-09-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P1810': [{'snaktype': 'value',
#          'property': 'P1810',
#          'hash': '66ca003c13da5ad42223ff7317b390a3bacdf896',
#          'datavalue': {'value': 'Chuck Tingle', 'type': 'string'},
#          'datatype': 'string'}],
#        'P3744': [{'snaktype': 'value',
#          'property': 'P3744',
#          'hash': '1deea468d2c20f554ebd2c145d1c69620feed8db',
#          'datavalue': {'value': {'amount': '+540', 'unit': '1'},
#           'type': 'quantity'},
#          'datatype': 'quantity'}]},
#       'qualifiers-order': ['P585', 'P1810', 'P3744'],
#       'id': 'Q20090453$6b10fdc2-4121-6c81-c980-a30c6549846d',
#       'rank': 'normal'}],
#     'P4862': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P4862',
#        'hash': '1b7ed325b97b609fd42bf64262625b575756efa1',
#        'datavalue': {'value': 'B00SF2MTYK', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$b9f70a80-4d3b-b759-0911-2ed4d3567e51',
#       'rank': 'normal'}],
#     'P7400': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P7400',
#        'hash': '6ea90b014b942b7d229d4437f03db904747b2df2',
#        'datavalue': {'value': 'tinglechuck', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$e906a515-4cb4-5a17-4238-b26db9acdbd7',
#       'rank': 'normal'}],
#     'P244': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P244',
#        'hash': 'd2a8a9a75fee36d1a0eefefa18d9fd52119c58ac',
#        'datavalue': {'value': 'no2020003856', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$9f7a6fb6-4ed9-37a7-835f-0bdc58f56cc3',
#       'rank': 'normal'}],
#     'P735': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P735',
#        'hash': '5010929333a89f1191a9ffe60e0c60451efba7fa',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 989983,
#          'id': 'Q989983'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P1545': [{'snaktype': 'value',
#          'property': 'P1545',
#          'hash': '2a1ced1dca90648ea7e306acbadd74fc81a10722',
#          'datavalue': {'value': '1', 'type': 'string'},
#          'datatype': 'string'}]},
#       'qualifiers-order': ['P1545'],
#       'id': 'Q20090453$c8f93122-4d98-1fb8-e38d-efb6c501b64f',
#       'rank': 'normal'}],
#     'P214': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P214',
#        'hash': 'a975e8e5c80c6dc5dc2546b19d8c1072589b2ad1',
#        'datavalue': {'value': '13157949286965091795', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$bbcd9e97-4f3e-59c1-a47a-b492a8f350b1',
#       'rank': 'normal'}],
#     'P734': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P734',
#        'hash': 'eed0986614b390c042f125bef1d847c52417ffca',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 28147104,
#          'id': 'Q28147104'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$8556d0a9-49fe-8be3-39c2-6786670d33f8',
#       'rank': 'normal'}],
#     'P1412': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1412',
#        'hash': '7056615ebf0fbde82a3ca3bb9b2c481669a46eb1',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1860,
#          'id': 'Q1860'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q20090453$953c9980-439c-2a1c-f081-ce20812cd821',
#       'rank': 'normal'}],
#     'P1477': [{'mainsnak': {'snaktype': 'somevalue',
#        'property': 'P1477',
#        'hash': 'cd09ac634eea55279970ae047f08a29f682dc464',
#        'datatype': 'monolingualtext'},
#       'type': 'statement',
#       'id': 'Q20090453$286f563a-4986-2030-82f0-3059a8df0a88',
#       'rank': 'normal'}],
#     'P646': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P646',
#        'hash': 'd5116208a9de041488cd707e32e811e751b5973b',
#        'datavalue': {'value': '/m/013chs60', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$57ECD963-6BAE-4CE0-ADCF-C3EE2149CF18',
#       'rank': 'normal'}],
#     'P8687': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P8687',
#        'hash': 'c85e72116add3da756b5ce1e7764bb41e3385e76',
#        'datavalue': {'value': {'amount': '+69313', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P6552': [{'snaktype': 'value',
#          'property': 'P6552',
#          'hash': '093604e25b76787d0f5649f707207b57cbefd2d8',
#          'datavalue': {'value': '2996351899', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': 'd72999b5d1b0bb17c6af669714cd3ee35662fc97',
#          'datavalue': {'value': {'time': '+2021-01-03T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P6552', 'P585'],
#       'id': 'Q20090453$4a13a680-6e20-4c4a-b58a-b0f5efe94dcc',
#       'rank': 'normal'},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P8687',
#        'hash': '8cbde474c620927b02dfef46fb74d81fdc551ccf',
#        'datavalue': {'value': {'amount': '+83976', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P6552': [{'snaktype': 'value',
#          'property': 'P6552',
#          'hash': '093604e25b76787d0f5649f707207b57cbefd2d8',
#          'datavalue': {'value': '2996351899', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '65fb842711ebf4dd5d1904a3552d396ebce1e951',
#          'datavalue': {'value': {'time': '+2022-02-24T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P6552', 'P585'],
#       'id': 'Q20090453$54fa4d50-9684-4594-b2e6-6ae3d7c66218',
#       'rank': 'normal'},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P8687',
#        'hash': '8b6781392aec6215cfbda1210c73f61a3ab510c7',
#        'datavalue': {'value': {'amount': '+95228', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P6552': [{'snaktype': 'value',
#          'property': 'P6552',
#          'hash': '093604e25b76787d0f5649f707207b57cbefd2d8',
#          'datavalue': {'value': '2996351899', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '26c1f8e08cf3c87468695f3d5c8abdc737448ac7',
#          'datavalue': {'value': {'time': '+2023-02-09T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P6552', 'P585'],
#       'id': 'Q20090453$99e82266-7179-4ed8-a247-02a557f6a7a4',
#       'rank': 'preferred'},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P8687',
#        'hash': 'cfb6c9eaa33654cf8577c7933ba3c8514e73f5f4',
#        'datavalue': {'value': {'amount': '+6290',
#          'unit': '1',
#          'upperBound': '+6299',
#          'lowerBound': '+6290'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P2397': [{'snaktype': 'value',
#          'property': 'P2397',
#          'hash': 'f03f068f83799d737afd8e3a5fb3a3e393d5e254',
#          'datavalue': {'value': 'UCABaUlzWliHp6jFfLuRmUJg', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': 'a64287b829e579708742e47d0bfab96d2b094e58',
#          'datavalue': {'value': {'time': '+2024-02-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P2397', 'P585'],
#       'id': 'Q20090453$b5d9c911-75cb-44d1-8ce9-56fec5955f73',
#       'rank': 'preferred',
#       'references': [{'hash': '5204938f6bf4d034f23b4081eac3ebbf545b877a',
#         'snaks': {'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '959fb8f4e2f89a704d5ace8f54f64d331378b24c',
#            'datavalue': {'value': {'time': '+2024-02-28T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'e6e6374525f7d680f01ff599745f367fb1369b87',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 8056784,
#              'id': 'Q8056784'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P813', 'P248']}]}],
#     'P434': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P434',
#        'hash': '2409c6d8eac65d591057a15b2371f9d1e624385a',
#        'datavalue': {'value': '4bad8386-00d0-44d8-8ca7-b93513253675',
#         'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$b0aac2a6-606f-492f-bd06-ea7aea8c6c05',
#       'rank': 'normal',
#       'references': [{'hash': 'd82214a3008a473cf25476b79c323535be6a99e9',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '623cc8f0e2f65afe4d66b91962d354a2f3aa9a27',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14005,
#              'id': 'Q14005'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'f2245dc41aabfbdaedd88242c80199d198151390',
#            'datavalue': {'value': {'time': '+2022-05-11T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P813']}]}],
#     'P9307': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P9307',
#        'hash': '2656cef6d8b1a42ef7d4fe17f859b7bf0b8c1fc5',
#        'datavalue': {'value': 'Chuck_Tingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$9DC5F7B9-91A3-4540-9995-71EAE0A251DB',
#       'rank': 'normal'}],
#     'P3943': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3943',
#        'hash': '0232bc6fddfc2eac6c820c3ea9ee147f16426883',
#        'datavalue': {'value': 'drchucktingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$0d04d846-432c-e8e9-3ca6-d635b5594094',
#       'rank': 'normal'}],
#     'P12361': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P12361',
#        'hash': 'ed2c078334f74cd08585d0a6a4a473985f4bafd1',
#        'datavalue': {'value': 'chucktingle.bsky.social', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P12409': [{'snaktype': 'value',
#          'property': 'P12409',
#          'hash': 'cd43d836ce9b18314d3c1832887d78512d655176',
#          'datavalue': {'value': 'did:plc:4qmldhjmsvozldytrmot62gt',
#           'type': 'string'},
#          'datatype': 'external-id'}],
#        'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': '7bef53b653e136b7ccc827f441e05ff4c27f96b7',
#          'datavalue': {'value': {'time': '+2023-04-27T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P12409', 'P580'],
#       'id': 'Q20090453$72F5DC48-A20C-41E2-AB1E-0EE2F01E87E8',
#       'rank': 'normal'}],
#     'P11079': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P11079',
#        'hash': '786f081b977bf8113e419bd61ac1f7bb8d52ec41',
#        'datavalue': {'value': 'chucktingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$a1b415a6-4a0f-4deb-12d5-afee9bf8e861',
#       'rank': 'normal'}],
#     'P968': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P968',
#        'hash': '69c4eda2edc1f73384b0e7afaabc897f157ca9ed',
#        'datavalue': {'value': 'mailto:ChuckTheTingler@gmail.com',
#         'type': 'string'},
#        'datatype': 'url'},
#       'type': 'statement',
#       'id': 'Q20090453$25cf7a35-4ff5-a7a0-d3d5-39bf04aa2d10',
#       'rank': 'normal',
#       'references': [{'hash': '81e8d0365e6daef268866d630acf75374a91e61c',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'cb5a48c6ef5852b701274c4a96f6b1d1541d0436',
#            'datavalue': {'value': 'https://www.chucktingle.com/contact.html',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P2013': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2013',
#        'hash': 'b081d0d46c04217110dee20db3002f35df4186c7',
#        'datavalue': {'value': 'ChuckTingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P11705': [{'snaktype': 'value',
#          'property': 'P11705',
#          'hash': 'f6f282cda8562d092513f82e160c2f8c71d26926',
#          'datavalue': {'value': '467182280129498', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': '6564996e4cc18ce39c0d55c3dc25763edfd7c04b',
#          'datavalue': {'value': {'time': '+2015-08-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P11705', 'P580'],
#       'id': 'Q20090453$8aac2c67-4895-bef1-0ef8-107ae3b0fb3d',
#       'rank': 'normal'}],
#     'P2003': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2003',
#        'hash': '8936df6d19de2ed689294a29c14d60dfc0724c5f',
#        'datavalue': {'value': 'chucktingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$d0f5721d-4882-9e05-ac98-13a7bf52c963',
#       'rank': 'normal'}],
#     'P11892': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P11892',
#        'hash': 'd424ab68b66fc9fd13e0007c52214bb08b37bf8d',
#        'datavalue': {'value': 'chucktingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$c1ddefe4-4d7d-e190-1d47-4068b2d62292',
#       'rank': 'normal'}],
#     'P7085': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P7085',
#        'hash': '933a576966887dab0e3a708c6d29084145aed196',
#        'datavalue': {'value': 'realchucktingle', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q20090453$346bfc44-4400-a61d-844f-cfcbdfe532c8',
#       'rank': 'normal'}],
#     'P2397': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2397',
#        'hash': 'f03f068f83799d737afd8e3a5fb3a3e393d5e254',
#        'datavalue': {'value': 'UCABaUlzWliHp6jFfLuRmUJg', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'qualifiers': {'P11245': [{'snaktype': 'value',
#          'property': 'P11245',
#          'hash': '8263aa5ef427d913777f117c3b6643d69ba4ce82',
#          'datavalue': {'value': 'ChuckTingle', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': 'ae6d483739c32fd0d619a1996667706e6dcc4453',
#          'datavalue': {'value': {'time': '+2015-01-30T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P1810': [{'snaktype': 'value',
#          'property': 'P1810',
#          'hash': '66ca003c13da5ad42223ff7317b390a3bacdf896',
#          'datavalue': {'value': 'Chuck Tingle', 'type': 'string'},
#          'datatype': 'string'}],
#        'P3744': [{'snaktype': 'value',
#          'property': 'P3744',
#          'hash': 'aedca7238e802d7f4353abf690c841eaaeb5f67f',
#          'datavalue': {'value': {'amount': '+6290', 'unit': '1'},
#           'type': 'quantity'},
#          'datatype': 'quantity'}],
#        'P3740': [{'snaktype': 'value',
#          'property': 'P3740',
#          'hash': '7caabc345c8f455bf183ff35b87531b236e65106',
#          'datavalue': {'value': {'amount': '+36', 'unit': '1'},
#           'type': 'quantity'},
#          'datatype': 'quantity'}],
#        'P5436': [{'snaktype': 'value',
#          'property': 'P5436',
#          'hash': 'b6614b8ac11cced4ba5d784c0c9427cffdba78f8',
#          'datavalue': {'value': {'amount': '+160621', 'unit': '1'},
#           'type': 'quantity'},
#          'datatype': 'quantity'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '6ff2c79e42f2734a0d0313e2e28c132250c77f92',
#          'datavalue': {'value': {'time': '+2024-02-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P11245',
#        'P580',
#        'P1810',
#        'P3744',
#        'P3740',
#        'P5436',
#        'P585'],
#       'id': 'Q20090453$2f8993e3-4eee-9fb5-dbe1-92318c4fa18b',
#       'rank': 'normal'}],
#     'P1015': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1015',
#        'hash': 'f1beb15180a98f89697f8607c22a64c0072b9b7e',
#        'datavalue': {'value': '1691043608804', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'q20090453$9c4e6c9b-423d-84e0-d300-f80747634db2',
#       'rank': 'normal',
#       'references': [{'hash': '30d1c7d95e1864b9e9ccd1215c657fe85b5a02d3',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 54919,
#              'id': 'Q54919'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P214': [{'snaktype': 'value',
#            'property': 'P214',
#            'hash': 'a975e8e5c80c6dc5dc2546b19d8c1072589b2ad1',
#            'datavalue': {'value': '13157949286965091795', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '810e7f2e3581b17e3b0fcd3bd31fc920815c4456',
#            'datavalue': {'value': {'time': '+2024-03-15T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P214', 'P813']}]}],
#     'P213': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P213',
#        'hash': '93e2b2cf7dfc195e210607bf5ef03672ce68a50d',
#        'datavalue': {'value': '0000000501148258', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'q20090453$cf10fdb5-41a6-a8fe-ed93-91688e4d7170',
#       'rank': 'normal',
#       'references': [{'hash': '30d1c7d95e1864b9e9ccd1215c657fe85b5a02d3',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 54919,
#              'id': 'Q54919'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P214': [{'snaktype': 'value',
#            'property': 'P214',
#            'hash': 'a975e8e5c80c6dc5dc2546b19d8c1072589b2ad1',
#            'datavalue': {'value': '13157949286965091795', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '810e7f2e3581b17e3b0fcd3bd31fc920815c4456',
#            'datavalue': {'value': {'time': '+2024-03-15T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P214', 'P813']}]}],
#     'P18': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P18',
#        'hash': 'b0a423b36fb39c9e0d63ba32e155b3ac85af37ad',
#        'datavalue': {'value': 'Chuck Tingle by Gage Skidmore.jpg',
#         'type': 'string'},
#        'datatype': 'commonsMedia'},
#       'type': 'statement',
#       'id': 'Q20090453$8164cba5-4ab4-34ae-a82f-9650aacc1f7c',
#       'rank': 'normal'}],
#     'P373': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P373',
#        'hash': 'cdefcfdbce8bb314d7be6105f264fe0a2cc0c9ef',
#        'datavalue': {'value': 'Chuck Tingle', 'type': 'string'},
#        'datatype': 'string'},
#       'type': 'statement',
#       'id': 'Q20090453$495d23b9-f6e0-4f41-a20d-bd9abd0c29b9',
#       'rank': 'normal'}]},
#    'sitelinks': {'azbwiki': {'site': 'azbwiki',
#      'title': 'چاک تینقل',
#      'badges': []},
#     'commonswiki': {'site': 'commonswiki',
#      'title': 'Category:Chuck Tingle',
#      'badges': []},
#     'enwiki': {'site': 'enwiki', 'title': 'Chuck Tingle', 'badges': []},
#     'eswiki': {'site': 'eswiki', 'title': 'Chuck Tingle', 'badges': []},
#     'frwiki': {'site': 'frwiki', 'title': 'Chuck Tingle', 'badges': []}}}},
#  'success': 1}

# %%
@cache
def translateID(id):
    idText = access_wikidata(id, search=False).json()
    return idText["entities"][next(iter(idText["entities"]))]["labels"]["en"]["value"]

def unpackWikidata(pageJson):
    if(pageJson == "Error"): return "Error"
    
    data = {}
    properties = pageJson["entities"][list(pageJson["entities"])[0]]["claims"]
    for i in properties:
#         s = json.dumps(properties[i])
#         q = json.dumps(json.loads(s), indent=2)
#         print(q)
        try:
            if(properties[i][0]["type"] == "statement"):
                data[translateID(i)] = properties[i][0]["mainsnak"]["datavalue"]["value"]
        except:
            pass
            
    return data
            
    
#     for id in list(spot):
#         print(translateID(id))


unpackedData = {}
for i in authorInfo:
    print(i)
    unpackedData[i] = unpackWikidata(authorInfo[i])
    
unpackedData

# %%
for i in paulo:
    print(i, paulo[i], "\n")
# Out:
# Commons category Paulo Coelho
#
# VIAF ID 52700
#
# ISNI 0000000120981529
#
# MusicBrainz artist ID 6e855ecb-5e1c-4ca4-9bdd-1b365326c3fe
#
# Library of Congress authority ID n86099875
#
# GND ID 115703101
#
# NDL Authority ID 00512573
#
# date of birth {'time': '+1947-08-24T00:00:00Z', 'timezone': 0, 'before': 0, 'after': 0, 'precision': 11, 'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}
#
# NL CR AUT ID jn19990001432
#
# image Paulo Coelho 2007-04-09 001 (cropped).jpg
#
# instance of {'entity-type': 'item', 'numeric-id': 5, 'id': 'Q5'}
#
# place of birth {'entity-type': 'item', 'numeric-id': 8678, 'id': 'Q8678'}
#
# Freebase ID /m/0hb3r
#
# Bibliothèque nationale de France ID 121744693
#
# country of citizenship {'entity-type': 'item', 'numeric-id': 155, 'id': 'Q155'}
#
# CANTIC ID (former scheme) a10066895
#
# NORAF ID 90862476
#
# award received {'entity-type': 'item', 'numeric-id': 1535117, 'id': 'Q1535117'}
#
# occupation {'entity-type': 'item', 'numeric-id': 36180, 'id': 'Q36180'}
#
# IMDb ID nm0168723
#
# National Library of Spain ID XX1041627
#
# IdRef ID 030299837
#
# SBN author ID UM1V006521
#
# Libraries Australia ID 35967394
#
# SELIBR ID 256091
#
# NUKAT ID n96401435
#
# Portuguese National Library author ID 44950
#
# Nationale Thesaurus voor Auteursnamen ID 113442092
#
# BLPL author ID 11102
#
# given name {'entity-type': 'item', 'numeric-id': 18385147, 'id': 'Q18385147'}
#
# Munzinger person ID 00000022443
#
# Perlentaucher ID paulo-coelho
#
# work location {'entity-type': 'item', 'numeric-id': 2844, 'id': 'Q2844'}
#
# NNDB people ID 080/000133678
#
# employer {'entity-type': 'item', 'numeric-id': 1065, 'id': 'Q1065'}
#
# Discogs artist ID 944941
#
# X username paulocoelho
#
# topic's main category {'entity-type': 'item', 'numeric-id': 9067130, 'id': 'Q9067130'}
#
# Open Library ID OL66700A
#
# spouse {'entity-type': 'item', 'numeric-id': 5110851, 'id': 'Q5110851'}
#
# Facebook username paulocoelho
#
# influenced by {'entity-type': 'item', 'numeric-id': 184440, 'id': 'Q184440'}
#
# GTAA ID 222635
#
# AlloCiné person ID 196426
#
# Swedish Film Database person ID 391311
#
# member of {'entity-type': 'item', 'numeric-id': 337224, 'id': 'Q337224'}
#
# PORT person ID 184091
#
# FAST ID 177970
#
# Encyclopædia Britannica Online ID biography/Paulo-Coelho
#
# AllMovie person ID p523612
#
# ČSFD person ID 136230
#
# Kinopoisk person ID 223446
#
# Gran Enciclopèdia Catalana ID (former scheme) 0246076
#
# BiblioNet author ID 206
#
# Les Archives du spectacle person ID 11917
#
# Quora topic ID Paulo-Coelho
#
# Cultureel Woordenboek ID literatuur-internationaal/paulo-coelho
#
# Babelio author ID 3637
#
# BNMM authority ID 000035768
#
# notable work {'entity-type': 'item', 'numeric-id': 179021, 'id': 'Q179021'}
#
# lifestyle {'entity-type': 'item', 'numeric-id': 45996, 'id': 'Q45996'}
#
# NLA Trove people ID 1166765
#
# Itaú Cultural ID pessoa12524/paulo-coelho
#
# Myspace ID paulocoelho
#
# Online Books Page author ID Coelho, Paulo
#
# CONOR.SI ID 6423395
#
# Internet Speculative Fiction Database author ID 186416
#
# Amazon author ID B000AQ3HB8
#
# unmarried partner {'entity-type': 'item', 'numeric-id': 5110851, 'id': 'Q5110851'}
#
# family name {'entity-type': 'item', 'numeric-id': 21492932, 'id': 'Q21492932'}
#
# BNB person ID CoelhoPaulo
#
# SHARE Catalogue author ID 176388
#
# Academia Brasileira de Letras ID paulo-coelho
#
# languages spoken, written or signed {'entity-type': 'item', 'numeric-id': 5146, 'id': 'Q5146'}
#
# NooSFere author ID -49591
#
# Libris-URI tr57btwc35828g9
#
# Goodreads author ID 566
#
# name in native language {'text': 'Paulo Coelho', 'language': 'pt'}
#
# Last.fm ID Paulo+Coelho
#
# sex or gender {'entity-type': 'item', 'numeric-id': 6581097, 'id': 'Q6581097'}
#
# genre {'entity-type': 'item', 'numeric-id': 8261, 'id': 'Q8261'}
#
# Great Russian Encyclopedia Online ID (old version) 2105115
#
# Bitraga author ID 832
#
# different from {'entity-type': 'item', 'numeric-id': 46727943, 'id': 'Q46727943'}
#
# University of Barcelona authority ID (former scheme) a1317423
#
# writing language {'entity-type': 'item', 'numeric-id': 5146, 'id': 'Q5146'}
#
# BAnQ authority ID 0000389016
#
# TV Tropes ID Creator/PauloCoelho
#
# described by source {'entity-type': 'item', 'numeric-id': 67311526, 'id': 'Q67311526'}
#
# National Library of Korea ID KAC199605328
#
# BD Gest' author ID 10634
#
# Brockhaus Enzyklopädie online ID coelho-paulo
#
# abART person ID 78779
#
# Store norske leksikon ID Paulo_Coelho
#
# official blog URL https://paulocoelhoblog.com
#
# Treccani ID paulo-coelho
#
# Europeana entity agent/base/60692
#
# FantLab author ID 659
#
# Pontificia Università della Santa Croce ID 16968
#
# CoBiS author ID 95a5yja38danynad65b5yc1g6ruk4c8
#
# PLWABN ID 9810627981605606
#
# National Library of Brazil ID 000562324
#
# DBC author ID 87097968220629
#
# ELNET ID a11284535
#
# National Library of Russia ID 7716365
#
# RERO ID (obsolete) 02-A003113745
#
# NSK ID 000191527
#
# Lebanese National Library ID 13537
#
# National Library of Latvia ID 000023892
#
# National Library of Chile ID 000071398
#
# NACSIS-CAT author ID DA08817262
#
# National Library of Greece ID 70028
#
# Canadiana Authorities ID (former scheme) 1003C4169
#
# NLP ID (old) a0000001640728
#
# CCAB ID 000242764
#
# Deutsche Biographie (GND) ID 115703101
#
# Instagram username paulocoelho
#
# YouTube channel ID UC1kMqwpDLDHk2YRoae-THSg
#
# official website http://paulocoelhoblog.com/
#
# EGAXA ID vtls002320965
#
# National Library of Lithuania ID LNB:V*147543;=BK
#
# Yle topic ID 18-136565
#
# Penguin India author ID paulo-coelho
#
# IDU person ID 12441
#
# Hrvatska enciklopedija ID 12186
#
# Montreux Jazz Festival person ID 24755
#
# Fantastic Fiction author ID c/paulo-coelho
#
# ArhivX LOD 24002
#
# De Agostini ID Coelho,+Paulo
#
# WhoSampled artist ID Paulo-Coelho
#
# Goodreads character ID 47284
#
# Hoopla artist ID 319541284
#
# Internet Book Database of Fiction writer ID 3661
#
# Bibliopoche author ID 11491
#
# Worlds Without End author ID 4789
#
# Fandango person ID 131187
#
# Canadiana Name Authority ID ncf10416452
#
# National Library of Israel J9U ID 987007259875005171
#
# Slovak National Library (VIAF) ID vtls004491696
#
# Diamond Catalog ID for persons and organisations 51184
#
# Union Catalog of Armenian Libraries authority ID 18815
#
# CONOR.KS ID 366184
#
# Proleksis enciklopedija ID 15680
#
# social media followers {'amount': '+15483651', 'unit': '1'}
#
# participant in {'entity-type': 'item', 'numeric-id': 99318477, 'id': 'Q99318477'}
#
# Who's Who UK ID U249451
#
# Portal da Literatura ID 497
#
# TMDB person ID 94452
#
# SNK ID 148020
#
# LyricsTranslate ID paulo-coelho-lyrics.html
#
# Cyprus University of Technology ID 99609
#
# Podchaser creator ID 107ZzpvPib
#
# Festivaletteratura person ID 1479
#
# Kallías ID PE00186825
#
# Namuwiki ID 파울로 코엘료
#
# NE.se ID paulo-coelho
#
# CANTIC ID 981058511826706706
#
# BeWeb person ID 5889
#
# Lur Encyclopedic Dictionary ID 01303/eu_c_0738/c0738
#
# AdoroCinema person ID 196426
#
# Online PWN Encyclopedia ID 3887234
#
# Den Store Danske ID Paulo_Coelho
#
# MYmovies person ID 141858
#
# Prabook ID 121337
#
# iHeart podcast ID 30958831
#
# IxTheo authority ID 077416481
#
# Krugosvet article literatura/koelo-paulo
#
# educated at {'entity-type': 'item', 'numeric-id': 18474196, 'id': 'Q18474196'}
#
# supported sports team {'entity-type': 'item', 'numeric-id': 5014111, 'id': 'Q5014111'}
#
# Musik-Sammler.de artist ID 20714
#
# Golden ID Paulo_Coelho-J6ZN8
#
# affiliation string Sant Jordi Asociados
#
# Film.ru person ID paulo-koelo
#
# KBR person ID 14215382
#
# BookBrainz author ID 8e1914b7-89fd-4911-b8fc-9c4ed6171585
#
# University of Barcelona authority ID 981058511826706706
#
# Ivi person ID paulo-koelo
#
# National Library of Ireland ID vtls000335972
#
# UAE University Libraries ID a10000584
#
# CiNii Research ID 1140845216743448448
#
# Douban author ID 4566665
#
# NLC authorities 000350576
#
# BBC Things ID 0347ade7-9df2-4dcd-a46f-43011e3ba66c
#
# Cravo Albin artist ID artista/paulo-coelho-2
#
# The Literary Encyclopedia person ID 5704
#
# UOM ID 15890
#
# Kinobox person ID 1013718
#
# Gran Enciclopèdia Catalana ID paulo-coelho
#
# Listal ID paulo-coelho
#
# Parsifal cluster ID 74359
#
# WikiTree person ID Coelho_Souza-1
#
# WorldCat Entities ID E39PBJdcxFk7qvJrrBYjTXpdcP
#
# topic's main template {'entity-type': 'item', 'numeric-id': 14337867, 'id': 'Q14337867'}
#
# Douban personage ID 27256181
#
# Sceneweb artist ID 48294
